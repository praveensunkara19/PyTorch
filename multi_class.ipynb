# %%
import torch
import torch.nn as nn

# %%
# muticlass problem

class NeuralNet2(nn.Module):
    def __ini__(self, input_size, hidden_size, num_classes):
        super(NeuralNet2, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.linear2  = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.linear1(x)
        out = self.relu(out)
        out = self.linear2(out)

        # no softmax at the end
        return out

# %%
model = NeuralNet2(input_size=28*28, hidden_size=5, num_classes=3)
criterian = nn.CrossEntropyLoss() #applies Softmax
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = NeuralNet2(input_size=28*28, hidden_size=5, num_classes=3)
#       2 criterian = nn.CrossEntropyLoss()
#
# File c:\Users\prave\anaconda3\envs\pyTorch\Lib\site-packages\torch\nn\modules\module.py:485, in Module.__init__(self, *args, **kwargs)
#     483 # Backward compatibility: no args used to be allowed when call_super_init=False
#     484 if self.call_super_init is False and bool(kwargs):
# --> 485     raise TypeError(
#     486         f"{type(self).__name__}.__init__() got an unexpected keyword argument '{next(iter(kwargs))}'"
#     487         ""
#     488     )
#     490 if self.call_super_init is False and bool(args):
#     491     raise TypeError(
#     492         f"{type(self).__name__}.__init__() takes 1 positional argument but {len(args) + 1} were"
#     493         " given"
#     494     )
#
# TypeError: NeuralNet2.__init__() got an unexpected keyword argument 'input_size'
